# %% [markdown]
# **Please set up your credentials JSON as GCP_CREDENTIALS secrets**

# %%
# !pip install google

import os
# from google.colab import userdata


os.environ["DESTINATION__CREDENTIALS"] = ".creds/gcs.json"
os.environ["BUCKET_URL"] = "gs://de_side_project_dezoomcamp_hw3_2026_2"
# Out:
# Requirement already satisfied: google in ./.venv/lib/python3.12/site-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.12/site-packages (from google) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in ./.venv/lib/python3.12/site-packages (from beautifulsoup4->google) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./.venv/lib/python3.12/site-packages (from beautifulsoup4->google) (4.15.0)

# %%
# Install for production
# %%capture
# !pip install dlt
# !pip install "dlt[bigquery, gs]"
# Out:
# Requirement already satisfied: dlt in ./.venv/lib/python3.12/site-packages (1.21.0)
# Requirement already satisfied: click>=7.1 in ./.venv/lib/python3.12/site-packages (from dlt) (8.3.1)
# Requirement already satisfied: fsspec>=2022.4.0 in ./.venv/lib/python3.12/site-packages (from dlt) (2026.2.0)
# Requirement already satisfied: gitpython>=3.1.29 in ./.venv/lib/python3.12/site-packages (from dlt) (3.1.46)
# Requirement already satisfied: giturlparse>=0.10.0 in ./.venv/lib/python3.12/site-packages (from dlt) (0.14.0)
# Requirement already satisfied: humanize>=4.4.0 in ./.venv/lib/python3.12/site-packages (from dlt) (4.15.0)
# Requirement already satisfied: jsonpath-ng>=1.5.3 in ./.venv/lib/python3.12/site-packages (from dlt) (1.7.0)
# Requirement already satisfied: orjson!=3.10.1,!=3.9.11,!=3.9.12,!=3.9.13,!=3.9.14,<4,>=3.6.7 in ./.venv/lib/python3.12/site-packages (from dlt) (3.11.7)
# Requirement already satisfied: packaging>=21.1 in ./.venv/lib/python3.12/site-packages (from dlt) (26.0)
# Requirement already satisfied: pathvalidate>=2.5.2 in ./.venv/lib/python3.12/site-packages (from dlt) (3.3.1)
# Requirement already satisfied: pendulum>=2.1.2 in ./.venv/lib/python3.12/site-packages (from dlt) (3.2.0)
# Requirement already satisfied: pluggy>=1.3.0 in ./.venv/lib/python3.12/site-packages (from dlt) (1.6.0)
# Requirement already satisfied: pytz>=2022.6 in ./.venv/lib/python3.12/site-packages (from dlt) (2025.2)
# Requirement already satisfied: pyyaml>=5.4.1 in ./.venv/lib/python3.12/site-packages (from dlt) (6.0.3)
# Requirement already satisfied: requests>=2.26.0 in ./.venv/lib/python3.12/site-packages (from dlt) (2.32.5)
# Requirement already satisfied: requirements-parser>=0.5.0 in ./.venv/lib/python3.12/site-packages (from dlt) (0.13.0)
# Requirement already satisfied: rich-argparse>=1.6.0 in ./.venv/lib/python3.12/site-packages (from dlt) (1.7.2)
# Requirement already satisfied: semver>=3.0.0 in ./.venv/lib/python3.12/site-packages (from dlt) (3.0.4)
# Requirement already satisfied: setuptools>=65.6.0 in ./.venv/lib/python3.12/site-packages (from dlt) (82.0.0)
# Requirement already satisfied: simplejson>=3.17.5 in ./.venv/lib/python3.12/site-packages (from dlt) (3.20.2)
# Requirement already satisfied: sqlglot!=28.1,>=25.4.0 in ./.venv/lib/python3.12/site-packages (from dlt) (28.10.1)
# Requirement already satisfied: tenacity>=8.0.2 in ./.venv/lib/python3.12/site-packages (from dlt) (9.1.4)
# Requirement already satisfied: tomlkit>=0.11.3 in ./.venv/lib/python3.12/site-packages (from dlt) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.12/site-packages (from dlt) (4.15.0)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.12/site-packages (from dlt) (2025.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.12/site-packages (from gitpython>=3.1.29->dlt) (4.0.12)
# Requirement already satisfied: ply in ./.venv/lib/python3.12/site-packages (from jsonpath-ng>=1.5.3->dlt) (3.11)
# Requirement already satisfied: python-dateutil>=2.6 in ./.venv/lib/python3.12/site-packages (from pendulum>=2.1.2->dlt) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt) (2026.1.4)
# Requirement already satisfied: rich>=11.0.0 in ./.venv/lib/python3.12/site-packages (from rich-argparse>=1.6.0->dlt) (14.3.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt) (5.0.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.6->pendulum>=2.1.2->dlt) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=11.0.0->rich-argparse>=1.6.0->dlt) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich>=11.0.0->rich-argparse>=1.6.0->dlt) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=11.0.0->rich-argparse>=1.6.0->dlt) (0.1.2)
# Requirement already satisfied: dlt[bigquery,gs] in ./.venv/lib/python3.12/site-packages (1.21.0)
# Requirement already satisfied: click>=7.1 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (8.3.1)
# Requirement already satisfied: fsspec>=2022.4.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (2026.2.0)
# Requirement already satisfied: gitpython>=3.1.29 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (3.1.46)
# Requirement already satisfied: giturlparse>=0.10.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (0.14.0)
# Requirement already satisfied: humanize>=4.4.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (4.15.0)
# Requirement already satisfied: jsonpath-ng>=1.5.3 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (1.7.0)
# Requirement already satisfied: orjson!=3.10.1,!=3.9.11,!=3.9.12,!=3.9.13,!=3.9.14,<4,>=3.6.7 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (3.11.7)
# Requirement already satisfied: packaging>=21.1 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (26.0)
# Requirement already satisfied: pathvalidate>=2.5.2 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (3.3.1)
# Requirement already satisfied: pendulum>=2.1.2 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (3.2.0)
# Requirement already satisfied: pluggy>=1.3.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (1.6.0)
# Requirement already satisfied: pytz>=2022.6 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (2025.2)
# Requirement already satisfied: pyyaml>=5.4.1 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (6.0.3)
# Requirement already satisfied: requests>=2.26.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (2.32.5)
# Requirement already satisfied: requirements-parser>=0.5.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (0.13.0)
# Requirement already satisfied: rich-argparse>=1.6.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (1.7.2)
# Requirement already satisfied: semver>=3.0.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (3.0.4)
# Requirement already satisfied: setuptools>=65.6.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (82.0.0)
# Requirement already satisfied: simplejson>=3.17.5 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (3.20.2)
# Requirement already satisfied: sqlglot!=28.1,>=25.4.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (28.10.1)
# Requirement already satisfied: tenacity>=8.0.2 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (9.1.4)
# Requirement already satisfied: tomlkit>=0.11.3 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (4.15.0)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (2025.3)
# Requirement already satisfied: db-dtypes>=1.2.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (1.5.0)
# Requirement already satisfied: gcsfs>=2022.4.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (2026.2.0)
# Requirement already satisfied: google-cloud-bigquery>=2.26.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (3.40.0)
# Requirement already satisfied: grpcio>=1.50.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (1.78.0)
# Requirement already satisfied: pyarrow>=16.0.0 in ./.venv/lib/python3.12/site-packages (from dlt[bigquery,gs]) (23.0.0)
# Requirement already satisfied: numpy>=1.24.0 in ./.venv/lib/python3.12/site-packages (from db-dtypes>=1.2.0->dlt[bigquery,gs]) (2.4.2)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in ./.venv/lib/python3.12/site-packages (from db-dtypes>=1.2.0->dlt[bigquery,gs]) (2.3.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./.venv/lib/python3.12/site-packages (from gcsfs>=2022.4.0->dlt[bigquery,gs]) (3.13.3)
# Requirement already satisfied: decorator>4.1.2 in ./.venv/lib/python3.12/site-packages (from gcsfs>=2022.4.0->dlt[bigquery,gs]) (5.2.1)
# Requirement already satisfied: google-auth>=1.2 in ./.venv/lib/python3.12/site-packages (from gcsfs>=2022.4.0->dlt[bigquery,gs]) (2.48.0)
# Requirement already satisfied: google-auth-oauthlib in ./.venv/lib/python3.12/site-packages (from gcsfs>=2022.4.0->dlt[bigquery,gs]) (1.2.4)
# Requirement already satisfied: google-cloud-storage>=3.9.0 in ./.venv/lib/python3.12/site-packages (from gcsfs>=2022.4.0->dlt[bigquery,gs]) (3.9.0)
# Requirement already satisfied: google-cloud-storage-control in ./.venv/lib/python3.12/site-packages (from gcsfs>=2022.4.0->dlt[bigquery,gs]) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.12/site-packages (from gitpython>=3.1.29->dlt[bigquery,gs]) (4.0.12)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.1 in ./.venv/lib/python3.12/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery,gs]) (2.29.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in ./.venv/lib/python3.12/site-packages (from google-cloud-bigquery>=2.26.0->dlt[bigquery,gs]) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from google-cloud-bigquery>=2.26.0->dlt[bigquery,gs]) (2.8.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in ./.venv/lib/python3.12/site-packages (from google-cloud-bigquery>=2.26.0->dlt[bigquery,gs]) (2.9.0.post0)
# Requirement already satisfied: ply in ./.venv/lib/python3.12/site-packages (from jsonpath-ng>=1.5.3->dlt[bigquery,gs]) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt[bigquery,gs]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt[bigquery,gs]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt[bigquery,gs]) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt[bigquery,gs]) (2026.1.4)
# Requirement already satisfied: rich>=11.0.0 in ./.venv/lib/python3.12/site-packages (from rich-argparse>=1.6.0->dlt[bigquery,gs]) (14.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery,gs]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery,gs]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery,gs]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery,gs]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery,gs]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery,gs]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery,gs]) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt[bigquery,gs]) (5.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in ./.venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery,gs]) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in ./.venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery,gs]) (6.33.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in ./.venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery,gs]) (1.27.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in ./.venv/lib/python3.12/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery,gs]) (1.78.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery,gs]) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery,gs]) (46.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery,gs]) (4.9.1)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in ./.venv/lib/python3.12/site-packages (from google-cloud-storage>=3.9.0->gcsfs>=2022.4.0->dlt[bigquery,gs]) (1.8.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery>=2.26.0->dlt[bigquery,gs]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=11.0.0->rich-argparse>=1.6.0->dlt[bigquery,gs]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich>=11.0.0->rich-argparse>=1.6.0->dlt[bigquery,gs]) (2.19.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.12/site-packages (from google-auth-oauthlib->gcsfs>=2022.4.0->dlt[bigquery,gs]) (2.0.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in ./.venv/lib/python3.12/site-packages (from google-cloud-storage-control->gcsfs>=2022.4.0->dlt[bigquery,gs]) (0.14.3)
# Requirement already satisfied: cffi>=2.0.0 in ./.venv/lib/python3.12/site-packages (from cryptography>=38.0.3->google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery,gs]) (2.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=11.0.0->rich-argparse>=1.6.0->dlt[bigquery,gs]) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery,gs]) (0.6.2)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2022.4.0->dlt[bigquery,gs]) (3.3.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery,gs]) (3.0)

# %%
# Install for testing
# %%capture
# !pip install dlt[duckdb]
# Out:
# Requirement already satisfied: dlt[duckdb] in ./.venv/lib/python3.12/site-packages (1.21.0)
# Requirement already satisfied: click>=7.1 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (8.3.1)
# Requirement already satisfied: fsspec>=2022.4.0 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (2026.2.0)
# Requirement already satisfied: gitpython>=3.1.29 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (3.1.46)
# Requirement already satisfied: giturlparse>=0.10.0 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (0.14.0)
# Requirement already satisfied: humanize>=4.4.0 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (4.15.0)
# Requirement already satisfied: jsonpath-ng>=1.5.3 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (1.7.0)
# Requirement already satisfied: orjson!=3.10.1,!=3.9.11,!=3.9.12,!=3.9.13,!=3.9.14,<4,>=3.6.7 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (3.11.7)
# Requirement already satisfied: packaging>=21.1 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (26.0)
# Requirement already satisfied: pathvalidate>=2.5.2 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (3.3.1)
# Requirement already satisfied: pendulum>=2.1.2 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (3.2.0)
# Requirement already satisfied: pluggy>=1.3.0 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (1.6.0)
# Requirement already satisfied: pytz>=2022.6 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (2025.2)
# Requirement already satisfied: pyyaml>=5.4.1 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (6.0.3)
# Requirement already satisfied: requests>=2.26.0 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (2.32.5)
# Requirement already satisfied: requirements-parser>=0.5.0 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (0.13.0)
# Requirement already satisfied: rich-argparse>=1.6.0 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (1.7.2)
# Requirement already satisfied: semver>=3.0.0 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (3.0.4)
# Requirement already satisfied: setuptools>=65.6.0 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (82.0.0)
# Requirement already satisfied: simplejson>=3.17.5 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (3.20.2)
# Requirement already satisfied: sqlglot!=28.1,>=25.4.0 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (28.10.1)
# Requirement already satisfied: tenacity>=8.0.2 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (9.1.4)
# Requirement already satisfied: tomlkit>=0.11.3 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (4.15.0)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (2025.3)
# Requirement already satisfied: duckdb>=0.9 in ./.venv/lib/python3.12/site-packages (from dlt[duckdb]) (1.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.12/site-packages (from gitpython>=3.1.29->dlt[duckdb]) (4.0.12)
# Requirement already satisfied: ply in ./.venv/lib/python3.12/site-packages (from jsonpath-ng>=1.5.3->dlt[duckdb]) (3.11)
# Requirement already satisfied: python-dateutil>=2.6 in ./.venv/lib/python3.12/site-packages (from pendulum>=2.1.2->dlt[duckdb]) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt[duckdb]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt[duckdb]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt[duckdb]) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt[duckdb]) (2026.1.4)
# Requirement already satisfied: rich>=11.0.0 in ./.venv/lib/python3.12/site-packages (from rich-argparse>=1.6.0->dlt[duckdb]) (14.3.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt[duckdb]) (5.0.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.6->pendulum>=2.1.2->dlt[duckdb]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=11.0.0->rich-argparse>=1.6.0->dlt[duckdb]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich>=11.0.0->rich-argparse>=1.6.0->dlt[duckdb]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=11.0.0->rich-argparse>=1.6.0->dlt[duckdb]) (0.1.2)

# %%
# !pip install dlt
# !pip install requests
# !pip install pandas

import dlt
import requests
import pandas as pd
from dlt.destinations import filesystem
from io import BytesIO
# Out:
# Requirement already satisfied: dlt in ./.venv/lib/python3.12/site-packages (1.21.0)
# Requirement already satisfied: click>=7.1 in ./.venv/lib/python3.12/site-packages (from dlt) (8.3.1)
# Requirement already satisfied: fsspec>=2022.4.0 in ./.venv/lib/python3.12/site-packages (from dlt) (2026.2.0)
# Requirement already satisfied: gitpython>=3.1.29 in ./.venv/lib/python3.12/site-packages (from dlt) (3.1.46)
# Requirement already satisfied: giturlparse>=0.10.0 in ./.venv/lib/python3.12/site-packages (from dlt) (0.14.0)
# Requirement already satisfied: humanize>=4.4.0 in ./.venv/lib/python3.12/site-packages (from dlt) (4.15.0)
# Requirement already satisfied: jsonpath-ng>=1.5.3 in ./.venv/lib/python3.12/site-packages (from dlt) (1.7.0)
# Requirement already satisfied: orjson!=3.10.1,!=3.9.11,!=3.9.12,!=3.9.13,!=3.9.14,<4,>=3.6.7 in ./.venv/lib/python3.12/site-packages (from dlt) (3.11.7)
# Requirement already satisfied: packaging>=21.1 in ./.venv/lib/python3.12/site-packages (from dlt) (26.0)
# Requirement already satisfied: pathvalidate>=2.5.2 in ./.venv/lib/python3.12/site-packages (from dlt) (3.3.1)
# Requirement already satisfied: pendulum>=2.1.2 in ./.venv/lib/python3.12/site-packages (from dlt) (3.2.0)
# Requirement already satisfied: pluggy>=1.3.0 in ./.venv/lib/python3.12/site-packages (from dlt) (1.6.0)
# Requirement already satisfied: pytz>=2022.6 in ./.venv/lib/python3.12/site-packages (from dlt) (2025.2)
# Requirement already satisfied: pyyaml>=5.4.1 in ./.venv/lib/python3.12/site-packages (from dlt) (6.0.3)
# Requirement already satisfied: requests>=2.26.0 in ./.venv/lib/python3.12/site-packages (from dlt) (2.32.5)
# Requirement already satisfied: requirements-parser>=0.5.0 in ./.venv/lib/python3.12/site-packages (from dlt) (0.13.0)
# Requirement already satisfied: rich-argparse>=1.6.0 in ./.venv/lib/python3.12/site-packages (from dlt) (1.7.2)
# Requirement already satisfied: semver>=3.0.0 in ./.venv/lib/python3.12/site-packages (from dlt) (3.0.4)
# Requirement already satisfied: setuptools>=65.6.0 in ./.venv/lib/python3.12/site-packages (from dlt) (82.0.0)
# Requirement already satisfied: simplejson>=3.17.5 in ./.venv/lib/python3.12/site-packages (from dlt) (3.20.2)
# Requirement already satisfied: sqlglot!=28.1,>=25.4.0 in ./.venv/lib/python3.12/site-packages (from dlt) (28.10.1)
# Requirement already satisfied: tenacity>=8.0.2 in ./.venv/lib/python3.12/site-packages (from dlt) (9.1.4)
# Requirement already satisfied: tomlkit>=0.11.3 in ./.venv/lib/python3.12/site-packages (from dlt) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.12/site-packages (from dlt) (4.15.0)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.12/site-packages (from dlt) (2025.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.12/site-packages (from gitpython>=3.1.29->dlt) (4.0.12)
# Requirement already satisfied: ply in ./.venv/lib/python3.12/site-packages (from jsonpath-ng>=1.5.3->dlt) (3.11)
# Requirement already satisfied: python-dateutil>=2.6 in ./.venv/lib/python3.12/site-packages (from pendulum>=2.1.2->dlt) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->dlt) (2026.1.4)
# Requirement already satisfied: rich>=11.0.0 in ./.venv/lib/python3.12/site-packages (from rich-argparse>=1.6.0->dlt) (14.3.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt) (5.0.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.6->pendulum>=2.1.2->dlt) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=11.0.0->rich-argparse>=1.6.0->dlt) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich>=11.0.0->rich-argparse>=1.6.0->dlt) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=11.0.0->rich-argparse>=1.6.0->dlt) (0.1.2)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests) (2026.1.4)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 5
#       2 get_ipython().system('pip install requests')
#       3 get_ipython().system('pip install pandas')
# ----> 5 import dlt
#       6 import requests
#       7 import pandas as pd
#
# ModuleNotFoundError: No module named 'dlt'

# %% [markdown]
# Ingesting parquet files to GCS.

# %%
# Define a dlt source to download and process Parquet files as resources
@dlt.source(name="rides")
def download_parquet():
    prefix = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata"
    for month in range(1, 7):
        file_name = f"yellow_tripdata_2024-0{month}.parquet"
        url = f"{prefix}_2024-0{month}.parquet"
        response = requests.get(url)

        df = pd.read_parquet(BytesIO(response.content))

        # Return the dataframe as a dlt resource for ingestion
        yield dlt.resource(df, name=file_name)


# Initialize the pipeline
pipeline = dlt.pipeline(
    pipeline_name="rides_pipeline",
    destination=filesystem(layout="{schema_name}/{table_name}.{ext}"),
    dataset_name="rides_dataset",
)

# Run the pipeline to load Parquet data into DuckDB
load_info = pipeline.run(download_parquet(), loader_file_format="parquet")

# Print the results
print(load_info)

# %% [markdown]
# Ingesting data to Database

# %%
# Define a dlt resource to download and process Parquet files as single table
@dlt.resource(name="rides", write_disposition="replace")
def download_parquet():
    prefix = 'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata'

    for month in range(1, 7):
        url = f"{prefix}_2024-0{month}.parquet"
        response = requests.get(url)

        df = pd.read_parquet(BytesIO(response.content))

        yield df


# Initialize the pipeline
pipeline = dlt.pipeline(
    pipeline_name="rides_pipeline",
    destination="duckdb",  # Use DuckDB for testing
    # destination="bigquery",  # Use BigQuery for production
    dataset_name="rides_dataset",
)

# Run the pipeline to load Parquet data into DuckDB
info = pipeline.run(download_parquet)

# Print the results
print(info)

# %%
import duckdb

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# Set search path to the dataset
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")

# Describe the dataset to see loaded tables
res = conn.sql("DESCRIBE").df()
print(res)

# %%
# provide a resource name to query a table of that name
with pipeline.sql_client() as client:
    with client.execute_query(f"SELECT count(1) FROM rides") as cursor:
        data = cursor.df()
print(data)
